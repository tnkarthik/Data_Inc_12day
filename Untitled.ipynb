# %%
import requests as requests

# %%
import simplejson as json

# %%
quandl_params = {'ticker': 'GOOG', 'date.gte': '20161127', 'date.lte': '20161229', 'api_key' : 'ruZerKYm8E-LFEPjXM_8'}

# %%
a = requests.get('https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json', params = quandl_params)

# %%
a.status_code == requests.codes.ok
# Out:
# True

# %%
a_text = json.loads(a.text)

# %%
colnames = [str(a_text['datatable']['columns'][i]['name']) for i in range(len(a_text['datatable']['columns']))]
data_type = [a_text['datatable']['columns'][i]['type'] for i in range(len(a_text['datatable']['columns']))]

# %%
a_text['datatable']['data'][0]
# Out:
# [u'GOOG',
#  u'2016-12-27',
#  790.68,
#  797.86,
#  787.657,
#  791.55,
#  785949.0,
#  0.0,
#  1.0,
#  790.68,
#  797.86,
#  787.657,
#  791.55,
#  785949.0]

# %%
len(colnames)
# Out:
# 14

# %%
len(a_text['datatable']['data'])
# Out:
# 3

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = colnames)

# %%
for i in range(len(a_text['datatable']['data'])):
               df2 = pd.DataFrame([a_text['datatable']['data'][i]], columns = colnames)
               df = df.append(df2)

# %%
df
# Out:
#   ticker        date    open      high       low   close     volume  \
# 0   GOOG  2016-11-28  760.00  779.5300  759.8000  768.24  2165938.0
# 0   GOOG  2016-11-29  771.53  778.5000  768.2400  770.84  1581782.0
# 0   GOOG  2016-11-30  770.07  772.9900  754.8300  758.04  2350596.0
# 0   GOOG  2016-12-01  757.44  759.8500  737.0245  747.92  2990682.0
# 0   GOOG  2016-12-02  744.59  754.0000  743.1000  750.50  1444185.0
# 0   GOOG  2016-12-05  757.71  763.9000  752.9000  762.52  1381864.0
# 0   GOOG  2016-12-06  764.73  768.8300  757.3400  759.11  1625210.0
# 0   GOOG  2016-12-07  761.00  771.3600  755.8000  771.19  1734177.0
# 0   GOOG  2016-12-08  772.48  778.1800  767.2300  776.42  1445445.0
# 0   GOOG  2016-12-09  780.00  789.4300  779.0210  789.29  1776827.0
# 0   GOOG  2016-12-12  785.04  791.2500  784.3554  789.27  2093977.0
# 0   GOOG  2016-12-13  793.90  804.3799  793.3400  796.10  2085270.0
# 0   GOOG  2016-12-14  797.40  804.0000  794.0100  797.07  1652691.0
# ...

# %%
import requests 
import simplejson as json
import pandas as pd

quandl_params = {'ticker': ticker, 'date.gte': date_begin, 'date.lte': date_end, 'api_key' : 'ruZerKYm8E-LFEPjXM_8'}

r = requests.get('https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json', params = quandl_params)
assert r.status_code == requests.codes.ok

r_text = json.loads(r.text)
n_col = len(r_text['datatable']['columns'])
colnames = [str(r_text['datatable']['columns'][i]['name']) for i in range(n_col)]

data = r_text['datatable']['data']
n_row = len(data)

## Create empty data frame

df = pd.DataFrame(columns = colnames)
df = df.append(pd.DataFrame(data, columns = colnames))

# %%
from plot_data import get_data

# %%
get_data()
# Out:
#   ticker        date    open      high       low   close     volume  \
# 0   GOOG  2016-11-29  771.53  778.5000  768.2400  770.84  1581782.0
# 0   GOOG  2016-11-30  770.07  772.9900  754.8300  758.04  2350596.0
# 0   GOOG  2016-12-01  757.44  759.8500  737.0245  747.92  2990682.0
# 0   GOOG  2016-12-02  744.59  754.0000  743.1000  750.50  1444185.0
# 0   GOOG  2016-12-05  757.71  763.9000  752.9000  762.52  1381864.0
# 0   GOOG  2016-12-06  764.73  768.8300  757.3400  759.11  1625210.0
# 0   GOOG  2016-12-07  761.00  771.3600  755.8000  771.19  1734177.0
# 0   GOOG  2016-12-08  772.48  778.1800  767.2300  776.42  1445445.0
# 0   GOOG  2016-12-09  780.00  789.4300  779.0210  789.29  1776827.0
# 0   GOOG  2016-12-12  785.04  791.2500  784.3554  789.27  2093977.0
# 0   GOOG  2016-12-13  793.90  804.3799  793.3400  796.10  2085270.0
# 0   GOOG  2016-12-14  797.40  804.0000  794.0100  797.07  1652691.0
# 0   GOOG  2016-12-15  797.34  803.0000  792.9200  797.85  1607120.0
# ...

# %%
ticker = 'GOOG'
date_begin = '20161101'
date_end = '20161229'

# %%
import plot_data

# %%
colnames
# Out:
# ['ticker',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'ex-dividend',
#  'split_ratio',
#  'adj_open',
#  'adj_high',
#  'adj_low',
#  'adj_close',
#  'adj_volume']

# %%
get_data()
# Out:
#   ticker        date    open      high       low   close     volume  \
# 0   GOOG  2016-11-29  771.53  778.5000  768.2400  770.84  1581782.0
# 0   GOOG  2016-11-30  770.07  772.9900  754.8300  758.04  2350596.0
# 0   GOOG  2016-12-01  757.44  759.8500  737.0245  747.92  2990682.0
# 0   GOOG  2016-12-02  744.59  754.0000  743.1000  750.50  1444185.0
# 0   GOOG  2016-12-05  757.71  763.9000  752.9000  762.52  1381864.0
# 0   GOOG  2016-12-06  764.73  768.8300  757.3400  759.11  1625210.0
# 0   GOOG  2016-12-07  761.00  771.3600  755.8000  771.19  1734177.0
# 0   GOOG  2016-12-08  772.48  778.1800  767.2300  776.42  1445445.0
# 0   GOOG  2016-12-09  780.00  789.4300  779.0210  789.29  1776827.0
# 0   GOOG  2016-12-12  785.04  791.2500  784.3554  789.27  2093977.0
# 0   GOOG  2016-12-13  793.90  804.3799  793.3400  796.10  2085270.0
# 0   GOOG  2016-12-14  797.40  804.0000  794.0100  797.07  1652691.0
# 0   GOOG  2016-12-15  797.34  803.0000  792.9200  797.85  1607120.0
# ...

# %%
from bokeh.charts import  show, output_file

# %%
from bokeh.charts import Line

# %%
output_file('templates/test1.html')

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6ebd677f-9bd7-4a77-903a-fb65b90b96e6">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import TimeSeries

# %%
p1 = figure(title = 'Simple bokeh plot test', x_axis_label = 'Time', y_axis_label = 'Stock Price')

# %%
p = TimeSeries(df, x = 'date', y = ['open','high'], color = ['open','high'], \
               dash = ['open','high'], title = 'Stock Price plot' , ylabel = 'Stock Prices', legend = True)

# %%
show(p)
# Out:
#     <div class="plotdiv" id="9dbcdadc-0147-496e-8217-976489c8dd9c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
from datetime import date, timedelta
date.today()
# Out:
# datetime.date(2016, 12, 30)

# %%
d= date.today()
d.strftime('%Y%m%d')
# Out:
# '20161230'

# %%
date.today().strftime('%Y%m%d')
# Out:
# '20161230'

# %%
(date.today()-timedelta(30)).strftime('%Y%m%d')
# Out:
# '20161130'

# %%
timedelta(30*24*3600)
# Out:
# datetime.timedelta(2592000)

# %%
selected_cols = ['open','high']

# %%
df[selected_cols]
# Out:
#       open      high
# 0   782.89  789.4900
# 1   778.20  781.6500
# 2   767.25  769.9500
# 3   750.66  770.3600
# 4   774.50  785.1900
# 5   783.40  795.6330
# 6   779.94  791.2265
# 7   791.17  791.1700
# 8   756.54  760.7800
# 9   755.60  757.8500
# 10  746.97  764.4162
# 11  755.20  766.3600
# 12  766.92  772.7000
# 13  771.37  775.0000
# 14  762.61  769.7000
# 15  772.63  776.9600
# 16  767.73  768.2825
# 17  764.26  765.0000
# 18  760.00  779.5300
# 19  771.53  778.5000
# 20  770.07  772.9900
# 21  757.44  759.8500
# 22  744.59  754.0000
# 23  757.71  763.9000
# 24  764.73  768.8300
# 25  761.00  771.3600
# 26  772.48  778.1800
# 27  780.00  789.4300
# 28  785.04  791.2500
# 29  793.90  804.3799
# 30  797.40  804.0000
# 31  797.34  803.0000
# 32  800.40  800.8558
# 33  790.22  797.6600
# 34  796.76  798.6500
# 35  795.84  796.6757
# 36  792.36  793.3200
# 37  790.90  792.7400
# 38  790.68  797.8600
# 39  793.70  794.2300
# 40  783.33  785.9300

# %%
a = list(df.columns)
a.remove('date')

# %%
print a
# Out:
# ['ticker', 'open', 'high', 'low', 'close', 'volume', 'ex-dividend', 'split_ratio', 'adj_open', 'adj_high', 'adj_low', 'adj_close', 'adj_volume']

# %%
import requests 
import simplejson as json
import pandas as pd
from datetime import date, timedelta

def get_data(ticker='GOOG',date_end = date.today().strftime('%Y%m%d'),\
             date_begin = (date.today()-timedelta(30)).strftime('%Y%m%d'),selected_cols = ['open','close']):
    
    ## Define the parameters to be passed to the query
    quandl_params = {'ticker': ticker, 'date.gte': date_begin, 'date.lte': date_end, 'api_key' : 'ruZerKYm8E-LFEPjXM_8'}
    
    ## Send data query
    r = requests.get('https://www.quandl.com/api/v3/datatables/WIKI/PRICES.json', params = quandl_params)
    
    ## Check if data query was successful
    assert r.status_code == requests.codes.ok

    ## Parse the JSON data and store it in dictionary data. n_row and n_col are num of rows and columns of the final data frame
    r_text = json.loads(r.text)
    n_col = len(r_text['datatable']['columns'])
    cols = [str(r_text['datatable']['columns'][i]['name']) for i in range(n_col)]

    data = r_text['datatable']['data']
    n_row = len(data)

    ## Store the data in pandas data frame df

    df = pd.DataFrame(data, columns = cols)
    
    return df[['date']+selected_cols]

# %%
list(get_data().columns)
# Out:
# ['ticker',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'ex-dividend',
#  'split_ratio',
#  'adj_open',
#  'adj_high',
#  'adj_low',
#  'adj_close',
#  'adj_volume']

# %%
from plot_data import get_data as gd
from plot_df import plot_df as pd

# %%
gd()
# Out:
#   ticker        date    open      high       low   close     volume  \
# 0   GOOG  2016-11-29  771.53  778.5000  768.2400  770.84  1581782.0
# 0   GOOG  2016-11-30  770.07  772.9900  754.8300  758.04  2350596.0
# 0   GOOG  2016-12-01  757.44  759.8500  737.0245  747.92  2990682.0
# 0   GOOG  2016-12-02  744.59  754.0000  743.1000  750.50  1444185.0
# 0   GOOG  2016-12-05  757.71  763.9000  752.9000  762.52  1381864.0
# 0   GOOG  2016-12-06  764.73  768.8300  757.3400  759.11  1625210.0
# 0   GOOG  2016-12-07  761.00  771.3600  755.8000  771.19  1734177.0
# 0   GOOG  2016-12-08  772.48  778.1800  767.2300  776.42  1445445.0
# 0   GOOG  2016-12-09  780.00  789.4300  779.0210  789.29  1776827.0
# 0   GOOG  2016-12-12  785.04  791.2500  784.3554  789.27  2093977.0
# 0   GOOG  2016-12-13  793.90  804.3799  793.3400  796.10  2085270.0
# 0   GOOG  2016-12-14  797.40  804.0000  794.0100  797.07  1652691.0
# 0   GOOG  2016-12-15  797.34  803.0000  792.9200  797.85  1607120.0
# ...

# %%
plot_df(gd())
# Out:
# INFO:bokeh.core.state:Session output file 'templates/stock_price.html' already exists, will be overwritten.
# ['open', 'high', 'low', 'close', 'volume', 'ex-dividend', 'split_ratio', 'adj_open', 'adj_high', 'adj_low', 'adj_close', 'adj_volume']
#   ticker        date    open    high       low   close     volume  \
# 0   GOOG  2016-11-29  771.53  778.50  768.2400  770.84  1581782.0
# 0   GOOG  2016-11-30  770.07  772.99  754.8300  758.04  2350596.0
# 0   GOOG  2016-12-01  757.44  759.85  737.0245  747.92  2990682.0
# 0   GOOG  2016-12-02  744.59  754.00  743.1000  750.50  1444185.0
# 0   GOOG  2016-12-05  757.71  763.90  752.9000  762.52  1381864.0
#
#    ex-dividend  split_ratio  adj_open  adj_high   adj_low  adj_close  \
# 0          0.0          1.0    771.53    778.50  768.2400     770.84
# 0          0.0          1.0    770.07    772.99  754.8300     758.04
# 0          0.0          1.0    757.44    759.85  737.0245     747.92
# ...
